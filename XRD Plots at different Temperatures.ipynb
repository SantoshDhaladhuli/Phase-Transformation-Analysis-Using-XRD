# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_excel("BTO-30.xlsx")
df2 = pd.read_excel("BTO-50.xlsx")
df3 = pd.read_excel("BTO-80.xlsx")
df4 = pd.read_excel("BTO-100.xlsx")
df5 = pd.read_excel("BTO-110.xlsx")
df6 = pd.read_excel("BTO-120.xlsx")
df7 = pd.read_excel("BTO-130.xlsx")
df8 = pd.read_excel("BTO-150.xlsx")

# %%
df8.tail()
# Out:
#      2-theta  Intensity
# 620   45.990   8.517638
# 621   45.992  12.520306
# 622   45.994  13.522973
# 623   45.996  13.525638
# 624   45.998  13.528301

# %%
df2["Intensity"] = df2["Intensity"] + 400
df3["Intensity"] = df3["Intensity"] + 800
df4["Intensity"] = df4["Intensity"] + 1000
df5["Intensity"] = df5["Intensity"] + 1300
df6["Intensity"] = df6["Intensity"] + 1600
df7["Intensity"] = df7["Intensity"] + 2000
df8["Intensity"] = df8["Intensity"] + 2000

# This is done to separate each of the peaks, therefore Intensities are no more relavent.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df8["2-theta"],df8["Intensity"],color = "black",label = "T = 150\N{DEGREE SIGN}C")

plt.plot(df7["2-theta"],df7["Intensity"],color = "orange",label = "T = 130\N{DEGREE SIGN}C")

plt.plot(df6["2-theta"],df6["Intensity"],color = "brown",label = "T = 120\N{DEGREE SIGN}C")

plt.plot(df5["2-theta"],df5["Intensity"],color = "purple",label = "T = 110\N{DEGREE SIGN}C")

plt.plot(df4["2-theta"],df4["Intensity"],color = "olive",label = "T = 100\N{DEGREE SIGN}C")

plt.plot(df3["2-theta"],df3["Intensity"],color = "green",label = "T = 80\N{DEGREE SIGN}C")

plt.plot(df2["2-theta"],df2["Intensity"],color = "blue",label = "T = 50\N{DEGREE SIGN}C")

plt.plot(df1["2-theta"],df1["Intensity"],color = "red",label = "T = 30\N{DEGREE SIGN}C")
plt.xlabel("Two-theta")
plt.ylabel("Intensity")
plt.legend()
plt.show()

# %% [markdown]
# # c/a Calculations

# %%
X = np.array([30,50,80,100,110,120,130,150])
y = np.array([1.01054877,1.009370,1.00731466,1.00704708,1.00579837,1.00588757,1.00168785,1.00044357])

# %%
plt.plot(X,y,color = "green")
plt.xlabel("Temperature in Celsius")
plt.ylabel("c/a ratio")
plt.show()
